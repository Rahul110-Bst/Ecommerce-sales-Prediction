# %% [markdown]
# # Data Understanding
#
# Dataset Name: Telco Customer Churn
#
# Total Rows: 7043
#
# Total Columns: 21
#
# Objective:
# Predict whether a customer will churn or not.

# %%
import pandas as pd

# %%
df = pd.read_csv("data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='str')

# %%
df.dtypes
# Out:
# customerID              str
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure                int64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges            str
# Churn                   str
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
df.describe(include="object")
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_1608\702825166.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     7590-VHVEG   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# # Data Cleaning
# ## Observation
#
# - Dataset contains 7043 customers.
# - Dataset has 21 features.
# - Churn rate is approximately 26%.
# - Around 74% customers are retained.
# - Missing values will be handled in the next step.

# %%
df_copy = df.copy()

# %%
df_copy.duplicated().sum()                   #duplicate values
# Out:
# np.int64(0)

# %%
df_copy.nunique()                              #identify categorical
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
df_copy["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df_copy["Churn"].value_counts(normalize=True) * 100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %% [markdown]
# # EDA (Exploratory Data Analysis (EDA)

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
#visualize graph in notebook

# %%
# %matplotlib inline

# %%
sns.set_style("whitegrid")                           #for graph clean background

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df_copy, x="Churn")
plt.title("Customer Churn Distribution")
plt.show()

# %%
churn_percentage = df_copy["Churn"].value_counts(normalize=True) * 100
print(churn_percentage)
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df_copy, x="gender", hue="Churn")
plt.title("Gender vs Churn")
plt.show()

# %%
plt.figure(figsize=(6,4))

sns.countplot(data=df_copy, x="SeniorCitizen", hue="Churn")

plt.title("Senior Citizen vs Churn")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(data=df_copy, x="Contract", hue="Churn")

plt.title("Contract Type vs Churn")

plt.show()

# %% [markdown]
# ### Observation
#
# - Customers with Month-to-Month contracts appear to churn more frequently.
# - Customers on longer contracts seem to have lower churn.
# - Gender does not appear to have a major impact on churn.

# %%
# Tenure Distribution
plt.figure(figsize=(8,5))
sns.histplot(data=df_copy, x="tenure", bins=30, kde=True)
plt.title("Distribution of Customer Tenure")
plt.xlabel("Tenure (Months)")
plt.ylabel("Number of Customers")
plt.show()

# %%
# Monthly charges Distrubution
plt.figure(figsize=(8,5))

sns.histplot(data=df_copy, x="MonthlyCharges", bins=30, kde=True)

plt.title("Distribution of Monthly Charges")
plt.xlabel("Monthly Charges")
plt.ylabel("Number of Customers")

plt.show()

# %%
#Monthly Charges vs Churn
plt.figure(figsize=(8,5))

sns.boxplot(data=df_copy, x="Churn", y="MonthlyCharges")

plt.title("Monthly Charges vs Churn")

plt.show()

# %%
#Tenure vs Churn
plt.figure(figsize=(8,5))

sns.boxplot(data=df_copy, x="Churn", y="tenure")

plt.title("Tenure vs Churn")

plt.show()

# %%
#Internet Service vs Churn
plt.figure(figsize=(8,5))

sns.countplot(data=df_copy, x="InternetService", hue="Churn")

plt.title("Internet Service vs Churn")

plt.show()

# %%
#payment Method vs churn
plt.figure(figsize=(10,5))

sns.countplot(data=df_copy, x="PaymentMethod", hue="Churn")

plt.xticks(rotation=20)

plt.title("Payment Method vs Churn")

plt.show()

# %% [markdown]
# ## Observations
#
# - Customers with shorter tenure appear to churn more.
# - Customers paying higher monthly charges seem to have higher churn.
# - Month-to-Month contracts have the highest churn.
# - Some payment methods appear to have higher churn than others.

# %%
# Data type issue solving of column Total charges
df_copy["TotalCharges"].head(10)
# Out:
# 0      29.85
# 1     1889.5
# 2     108.15
# 3    1840.75
# 4     151.65
# 5      820.5
# 6     1949.4
# 7      301.9
# 8    3046.05
# 9    3487.95
# Name: TotalCharges, dtype: str

# %%
df_copy["TotalCharges"].dtype
# Out:
# <StringDtype(na_value=nan)>

# %%
(df_copy["TotalCharges"] == " ").sum()
# Out:
# np.int64(11)

# %%
import numpy as np

df_copy["TotalCharges"] = df_copy["TotalCharges"].replace(" ", np.nan)

# %%
df_copy["TotalCharges"].isnull().sum()
# Out:
# np.int64(11)

# %%
df_copy["TotalCharges"] = pd.to_numeric(                    
    df_copy["TotalCharges"],
    errors="coerce"
)     #convert text to numner

# %%
df_copy["TotalCharges"].dtype
# Out:
# dtype('float64')

# %%
# missing value Analysis
df_copy.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
missing_percentage = (df_copy.isnull().sum() / len(df_copy)) * 100

missing_percentage
# Out:
# customerID          0.000000
# gender              0.000000
# SeniorCitizen       0.000000
# Partner             0.000000
# Dependents          0.000000
# tenure              0.000000
# PhoneService        0.000000
# MultipleLines       0.000000
# InternetService     0.000000
# OnlineSecurity      0.000000
# OnlineBackup        0.000000
# DeviceProtection    0.000000
# TechSupport         0.000000
# StreamingTV         0.000000
# StreamingMovies     0.000000
# Contract            0.000000
# PaperlessBilling    0.000000
# PaymentMethod       0.000000
# MonthlyCharges      0.000000
# TotalCharges        0.156183
# Churn               0.000000
# dtype: float64

# %%
# missing value remove due to less percentage 
df_copy = df_copy.dropna()

# %%
df_copy.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df_copy.shape
# Out:
# (7032, 21)

# %%
df_copy.to_csv(
    "data/processed/cleaned_telco_customer_churn.csv",
    index=False
)

# %%
#Numerical Feature Analysis
numerical_columns = ["tenure", "MonthlyCharges", "TotalCharges"]

df_copy[numerical_columns].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7032.000000     7032.000000   7032.000000
# mean     32.421786       64.798208   2283.300441
# std      24.545260       30.085974   2266.771362
# min       1.000000       18.250000     18.800000
# 25%       9.000000       35.587500    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.862500   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
# Correlation Analysis
correlation = df_copy[numerical_columns].corr()
correlation
# Out:
#                   tenure  MonthlyCharges  TotalCharges
# tenure          1.000000        0.246862      0.825880
# MonthlyCharges  0.246862        1.000000      0.651065
# TotalCharges    0.825880        0.651065      1.000000

# %%
plt.figure(figsize=(6,5))

sns.heatmap(
    correlation,
    annot=True,
    cmap="Blues",
    fmt=".2f"
)

plt.title("Correlation Heatmap")

plt.show()

# %%
contract_churn = pd.crosstab(
    df_copy["Contract"],
    df_copy["Churn"],
    normalize="index"
) * 100

contract_churn
# Out:
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.722826  11.277174
# Two year        97.151335   2.848665

# %%
contract_churn.plot(
    kind="bar",
    figsize=(8,5)
)

plt.title("Churn Percentage by Contract Type")

plt.ylabel("Percentage")

plt.show()

# %% [markdown]
# ## Observation
#
# - Month-to-Month customers have the highest churn.
# - One Year contract customers churn less.
# - Two Year contract customers are the most loyal.

# %%
# churn by payment mthod
payment_churn = pd.crosstab(
    df_copy["PaymentMethod"],
    df_copy["Churn"],
    normalize="index"
) * 100

payment_churn
# Out:
# Churn                             No        Yes
# PaymentMethod
# Bank transfer (automatic)  83.268482  16.731518
# Credit card (automatic)    84.746877  15.253123
# Electronic check           54.714588  45.285412
# Mailed check               80.798005  19.201995

# %%
payment_churn.plot(
    kind="bar",
    figsize=(10,5)
)

plt.title("Churn Percentage by Payment Method")

plt.ylabel("Percentage")

plt.xticks(rotation=20)

plt.show()

# %%
#Churn by Internet Service
internet_churn = pd.crosstab(
    df_copy["InternetService"],
    df_copy["Churn"],
    normalize="index"
) * 100

internet_churn
# Out:
# Churn                   No        Yes
# InternetService
# DSL              81.001656  18.998344
# Fiber optic      58.107235  41.892765
# No               92.565789   7.434211

# %%
internet_churn.plot(
    kind="bar",
    figsize=(8,5)
)

plt.title("Churn Percentage by Internet Service")

plt.ylabel("Percentage")

plt.show()

# %% [markdown]
# # Feature Enginnering

# %%
df_model = df_copy.drop(columns=["customerID"])

# %%
df_model.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
# x= features y= target
X = df_model.drop("Churn", axis=1)
y = df_model["Churn"]

# %%
print(X.shape)
print(y.shape)
# Out:
# (7032, 19)
# (7032,)

# %%
y.value_counts()
# Out:
# Churn
# No     5163
# Yes    1869
# Name: count, dtype: int64

# %%
#Encoding
X.dtypes
# Out:
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure                int64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges        float64
# dtype: object

# %%
# Categorical and numerical columns
categorical_columns = X.select_dtypes(include=["object", "string"]).columns
numerical_columns = X.select_dtypes(include=["int64", "float64"]).columns

# %%
print("Categorical Columns:")
print(categorical_columns)

print("\nNumerical Columns:")
print(numerical_columns)
# Out:
# Categorical Columns:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod'],
#       dtype='str')
#
# Numerical Columns:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges'], dtype='str')

# %%
X_encoded = pd.get_dummies(
    X,
    drop_first=True,
    dtype=int
)

# %%
print(X.shape)
print(X_encoded.shape)
# Out:
# (7032, 19)
# (7032, 30)

# %%
X_encoded.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 0              0       1           29.85         29.85            0
# 1              0      34           56.95       1889.50            1
# 2              0       2           53.85        108.15            1
# 3              0      45           42.30       1840.75            1
# 4              0       2           70.70        151.65            0
#
#    Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0            1               0                 0
# 1            0               0                 1
# 2            0               0                 1
# 3            0               0                 0
# 4            0               0                 1
#
#    MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 0                               1                  0  ...
# 1                               0                  0  ...
# 2                               0                  0  ...
# ...

# %%
y.unique()
# Out:
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
print(y[:5])
# Out:
# 0     No
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# Name: Churn, dtype: str

# %%
print(y_encoded[:5])
# Out:
# [0 0 1 0 1]

# %%
# Train test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded,
    y_encoded,
    test_size=0.2,
    random_state=42
)

# %%
print("X_train:", X_train.shape)

print("X_test :", X_test.shape)

print("y_train:", y_train.shape)

print("y_test :", y_test.shape)
# Out:
# X_train: (5625, 30)
# X_test : (1407, 30)
# y_train: (5625,)
# y_test : (1407,)

# %%
#standard scaler
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %%
print(X_train_scaled.shape)

print(X_test_scaled.shape)
# Out:
# (5625, 30)
# (1407, 30)

# %%
# Logistic Regreession
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(random_state=42)

# %%
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred = model.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7874911158493249

# %%
#classification Report
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      1033
#            1       0.62      0.52      0.56       374
#
#     accuracy                           0.79      1407
#    macro avg       0.73      0.70      0.71      1407
# weighted avg       0.78      0.79      0.78      1407

# %%
#confusion Matrix
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# [[915 118]
#  [181 193]]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_pred
)

plt.show()

# %% [markdown]
# ### Model 1: Logistic Regression
#
# - Accuracy: 0.787
# - Pros:
#   - Fast
#   - Easy to interpret
# - Cons:
#   - Assumes a linear relationship

# %%
# Decision tree
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model = DecisionTreeClassifier(
    random_state=42
)

# %%
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
X_train
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 6030              0      43           49.05       2076.20            0
# 3410              0       3           53.40        188.70            1
# 5483              0      55           77.75       4458.15            0
# 5524              0      45           54.65       2553.70            1
# 6337              0      55          100.90       5448.60            0
# ...             ...     ...             ...           ...          ...
# 3778              0       3           50.40        137.25            1
# 5199              0      51          111.50       5703.25            0
# 5235              0       9           81.15        784.45            1
# 5399              0      50           19.75        989.05            0
# 862               1      20           73.65       1463.50            1
#
#       Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 6030            0               0                 0
# ...

# %%
dt_pred = dt_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

dt_accuracy = accuracy_score(
    y_test,
    dt_pred
)

print(dt_accuracy)
# Out:
# 0.7249466950959488

# %%
#Random forest
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf_pred = rf_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

rf_accuracy = accuracy_score(
    y_test,
    rf_pred
)

print("Random Forest Accuracy:", rf_accuracy)
# Out:
# Random Forest Accuracy: 0.7853589196872779

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86      1033
#            1       0.63      0.48      0.54       374
#
#     accuracy                           0.79      1407
#    macro avg       0.73      0.69      0.70      1407
# weighted avg       0.77      0.79      0.78      1407

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

ConfusionMatrixDisplay.from_predictions(
    y_test,
    rf_pred
)

plt.show()

# %%
# feature importance
feature_importance = pd.DataFrame({
    "Feature": X_train.columns,
    "Importance": rf_model.feature_importances_
})

# %%
feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

# %%
feature_importance.head(10)
# Out:
#                            Feature  Importance
# 3                     TotalCharges    0.193409
# 2                   MonthlyCharges    0.169758
# 1                           tenure    0.167572
# 10     InternetService_Fiber optic    0.039999
# 28  PaymentMethod_Electronic check    0.035016
# 13              OnlineSecurity_Yes    0.028905
# 25               Contract_Two year    0.028618
# 4                      gender_Male    0.026971
# 19                 TechSupport_Yes    0.025829
# 26            PaperlessBilling_Yes    0.025044

# %%
import matplotlib.pyplot as plt

top10 = feature_importance.head(10)

plt.figure(figsize=(10,6))

plt.barh(top10["Feature"], top10["Importance"])

plt.xlabel("Importance")
plt.ylabel("Features")
plt.title("Top 10 Important Features")

plt.gca().invert_yaxis()

plt.show()

# %%
#model save(joblib)
import joblib

# %%
joblib.dump(
    rf_model,
    "models/random_forest_model.pkl"
)
# Out:
# ['models/random_forest_model.pkl']

# %%
joblib.dump(
    scaler,
    "models/scaler.pkl"
)
# Out:
# ['models/scaler.pkl']

# %%
X_train.columns.tolist()
# Out:
# ['SeniorCitizen',
#  'tenure',
#  'MonthlyCharges',
#  'TotalCharges',
#  'gender_Male',
#  'Partner_Yes',
#  'Dependents_Yes',
#  'PhoneService_Yes',
#  'MultipleLines_No phone service',
#  'MultipleLines_Yes',
#  'InternetService_Fiber optic',
#  'InternetService_No',
#  'OnlineSecurity_No internet service',
#  'OnlineSecurity_Yes',
#  'OnlineBackup_No internet service',
#  'OnlineBackup_Yes',
#  'DeviceProtection_No internet service',
#  'DeviceProtection_Yes',
#  'TechSupport_No internet service',
#  'TechSupport_Yes',
#  'StreamingTV_No internet service',
#  'StreamingTV_Yes',
#  'StreamingMovies_No internet service',
#  'StreamingMovies_Yes',
#  'Contract_One year',
#  'Contract_Two year',
#  'PaperlessBilling_Yes',
#  'PaymentMethod_Credit card (automatic)',
#  'PaymentMethod_Electronic check',
#  'PaymentMethod_Mailed check']
